# %% [markdown]
# <h1>The Adult Income dataset</h1>
#
# <h2>Description</h2>
#
#
# <h3>Title of dataset: adult.csv</h3>
#
# <b>Sources</b>:
#
# * Original owners of database - US Census Bureau
# * Donor of database - Ronny Kohavi and Barry Becker
# * Date received - 05/19/96
#
# <b>Number of Instances</b>:
#
# * 48842 instances, mix of continuous and discrete (train=32561, test=16281)
# * 45222 if instances with unknown values are removed (train=30162, test=15060)
# * Split into train-test using MLC++ GenCVFiles (2/3, 1/3 random).
#
# <b>Number of Attributes/Fearures/Columns</b>:
#
# * 6 continuous, 8 nominal attributes.
#
# <b>Attribute Information/Fearures/Columns</b>
#
# * age: continuous.
# * workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# * fnlwgt: continuous.
# * education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# * education-num: continuous.
# * marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# * occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# * relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# * race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# * sex: Female, Male.
# * capital-gain: continuous.
# * capital-loss: continuous.
# * hours-per-week: continuous.
# * native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# * income: >50K, <=50K
#
# <b>Missing Values</b>:
#
#  * 7% rows have missing values.

# %%
import numpy as np
import pandas as pd

# %%
missing=['?']
df=pd.read_csv('adult.csv',na_values=missing)

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                NaN    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %% [markdown]
# <b>OBSERVATION </b>: There are 48842 columns and 15 rows in given dataset

# %%
df.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  educational-num  \
# count   48842.000000     46043  4.884200e+04     48842     48842.000000
# unique           NaN         8           NaN        16              NaN
# top              NaN   Private           NaN   HS-grad              NaN
# freq             NaN     33906           NaN     15784              NaN
# mean       38.643585       NaN  1.896641e+05       NaN        10.078089
# std        13.710510       NaN  1.056040e+05       NaN         2.570973
# min        17.000000       NaN  1.228500e+04       NaN         1.000000
# 25%        28.000000       NaN  1.175505e+05       NaN         9.000000
# 50%        37.000000       NaN  1.781445e+05       NaN        10.000000
# 75%        48.000000       NaN  2.376420e+05       NaN        12.000000
# max        90.000000       NaN  1.490400e+06       NaN        16.000000
#
#             marital-status      occupation relationship   race gender  \
# ...

# %% [markdown]
# <b>OBSERVATION</b> : This a brief description of the dataset including categorical and numerical columns

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# <b>OBSERVATION</b> : This is brief description contaning only numerical type of columns

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        46043 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       46033 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   47985 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB
# age                   0
# ...

# %% [markdown]
# <b>OBSERVATION</b> : This info shows that there are missing values in 'occupation' = 2799, 'workclass' = 2809 and
#                       'native-country' = 857

# %%
round(df.isnull().sum()/len(df)*100,2)
# Out:
# age                0.00
# workclass          5.73
# fnlwgt             0.00
# education          0.00
# educational-num    0.00
# marital-status     0.00
# occupation         5.75
# relationship       0.00
# race               0.00
# gender             0.00
# capital-gain       0.00
# capital-loss       0.00
# hours-per-week     0.00
# native-country     1.75
# income             0.00
# dtype: float64

# %% [markdown]
# <b>OBSERVATION</b> : This observation shows the percentage of missing values present in each column

# %%
Q=df.income.value_counts()
print(Q)
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %% [markdown]
# <b>OBSERVATION</b> : This shows that income less than or equal to 50K is 37155 and great than 50K is 11687.

# %%
df.gender.value_counts()/df.gender.count()*100
# Out:
# Male      66.848204
# Female    33.151796
# Name: gender, dtype: float64

# %% [markdown]
# <b>OBSERVATION</b> : This shows the percentage of working of male and female

# %%
df.groupby('race').first()
# Out:
#                     age workclass  fnlwgt     education  educational-num  \
# race
# Amer-Indian-Eskimo   34   Private  198751       Masters               14
# Asian-Pac-Islander   40   Private   85019     Doctorate               16
# Black                25   Private  226802          11th                7
# Other                46   Private  269034  Some-college               10
# White                38   Private   89814       HS-grad                9
#
#                         marital-status         occupation   relationship  \
# race
# Amer-Indian-Eskimo       Never-married      Other-service  Not-in-family
# Asian-Pac-Islander  Married-civ-spouse     Prof-specialty        Husband
# Black                    Never-married  Machine-op-inspct      Own-child
# Other               Married-civ-spouse       Craft-repair        Husband
# White               Married-civ-spouse    Farming-fishing        Husband
#
#                    gender  capital-gain  capital-loss  hours-per-week  \
# ...

# %% [markdown]
# <b>OBSERVATION</b> : This shows the first values of all type of races.

# %%
pd.crosstab(df.gender,df.income)/df.income.count()*100
# Out:
# income      <=50K       >50K
# gender
# Female  29.529913   3.621883
# Male    46.541911  20.306294

# %% [markdown]
# <b>OBSERVATION</b> : Shows the percentage of male and female working above the income of 50K or below the income of 50K

# %%
df["marital-status"].value_counts()
# Out:
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64

# %% [markdown]
# <b>OBSERVATION</b> : Shows the values of marital-status of all the people

# %% [markdown]
# <h2>Finding and Treating the missing values in the given dataset</h2>

# %%
df[df.isnull().sum(axis=1) >=3]
# Out:
#        age workclass  fnlwgt     education  educational-num  \
# 2160    28       NaN  243190     Bachelors               13
# 2323    50       NaN  339547  Some-college               10
# 2584    47       NaN  163748       Masters               14
# 2612    27       NaN  258231       HS-grad                9
# 2774    27       NaN  132372       HS-grad                9
# 3074    23       NaN  264874     Assoc-voc               11
# 3671    24       NaN   35633  Some-college               10
# 3853    28       NaN  195568  Some-college               10
# 5052    21       NaN  156780  Some-college               10
# 5972    40       NaN   95049     Assoc-voc               11
# 6800    22       NaN  320451  Some-college               10
# 7231    23       NaN   35633  Some-college               10
# 10266   47       NaN  118358       HS-grad                9
# 10408   22       NaN   52596  Some-college               10
# 10508   18       NaN  193889  Some-college               10
# ...

# %% [markdown]
# <b>OBSERVATION</b> : This shows all the rows which contains atleast 3 missing values

# %%
df=df.dropna(how='any')
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %% [markdown]
# <b>OBSERVATION</b> : Removing all the rows which contain atleast 3 values

# %%
round(df.isnull().sum()/len(df.index)*100,2)
# Out:
# age                0.0
# workclass          0.0
# fnlwgt             0.0
# education          0.0
# educational-num    0.0
# marital-status     0.0
# occupation         0.0
# relationship       0.0
# race               0.0
# gender             0.0
# capital-gain       0.0
# capital-loss       0.0
# hours-per-week     0.0
# native-country     0.0
# income             0.0
# dtype: float64

# %% [markdown]
# <b>OBSERVAION</b> : This shows that now there is no missing values in dataset

# %%
#Droping the fnlwgt column

df=df.drop('fnlwgt', axis=1)
round(df.isnull().sum()/len(df.index)*100,2)
# Out:
# age                0.0
# workclass          0.0
# education          0.0
# educational-num    0.0
# marital-status     0.0
# occupation         0.0
# relationship       0.0
# race               0.0
# gender             0.0
# capital-gain       0.0
# capital-loss       0.0
# hours-per-week     0.0
# native-country     0.0
# income             0.0
# dtype: float64

# %%
(1-len(df.index)/48842)*100
# Out:
# 7.411653904426519

# %% [markdown]
# <b>OBSERVATION</b> : This shows that the column 'fnlwgt' has been dropped

# %% [markdown]
# <h2>Univariate Analysis</h2>

# %%
import plotly as ply
import seaborn as sns

# %%
df.describe()
# Out:
#                 age  educational-num  capital-gain  capital-loss  \
# count  45222.000000     45222.000000  45222.000000  45222.000000
# mean      38.547941        10.118460   1101.430344     88.595418
# std       13.217870         2.552881   7506.430084    404.956092
# min       17.000000         1.000000      0.000000      0.000000
# 25%       28.000000         9.000000      0.000000      0.000000
# 50%       37.000000        10.000000      0.000000      0.000000
# 75%       47.000000        13.000000      0.000000      0.000000
# max       90.000000        16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    45222.000000
# mean        40.938017
# std         12.007508
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
sns.boxplot(y='age',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows that average age of people lies between 35-40 and outliers are between 75-90

# %%
sns.boxplot(y='educational-num',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows that the average of educational-num is between 10-12 and outliers lies in between 0-3

# %%
sns.boxplot(y='capital-gain',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : this graph shows that the capital-gain  of people is close to 0 and aapproximately all values are in outliers

# %%
sns.boxplot(y='capital-loss',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows that the capital-loss is also close to 0 of many people and almost all value are outliers

# %%
sns.boxplot(y='hours-per-week',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows that average working hors per week is between 40-43 hours

# %%
import matplotlib.pyplot as plt
from sklearn import preprocessing
# %matplotlib inline

# %%
sns.countplot(y='workclass',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows that the following workclass are in this order:
#         - Private:above 30000
#         - and remaining all are below 5000

# %%
sns.countplot(y='education',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows that the education of people are in this way:
#                 - HS-grad:above 14000
#                 - Some-college:above 10000
#                 - Bachelors:between 7500-8000
#                 - Masters and Assoc-vac:above 2000
#                 - Rest all are below 2000

# %%
sns.countplot(y='marital-status',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows the marital-status:
#                     - Never-Married:Around 14000-15000
#                     - Married-civ-spouse:above 20000
#                     - Divorced:betweeen 5500-6000
#                     - Rest all are below 2500

# %%
sns.countplot(y='occupation',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows the occupation:
#                     - Other-service,prof-speciality,craft-repair,adm-clerical,exec-managerial,sales are above 5000
#                     - Machine-op-inspct,other-service,transport-moving,handlers-cleaners are above 2000
#                     - Rest all are below 2000

# %%
sns.countplot(y='relationship',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows the relationship:
#                     - Husband,not-in-family are above 10000
#                     - Rest all are below 7500

# %%
sns.countplot(y='race',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows the race:
#                     - White are above 35000
#                     - Rest all are below 5000

# %%
sns.countplot(y='gender',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows the gender:
#                     - Male:between 29000-30000
#                     - Female:between 14000-15000

# %%
sns.countplot(y='native-country',data=df)

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows the population of countries:
#                     - Most of the population is in United-states
#                     - Rest all countries have population of below 5000

# %%
hist_plot=df['hours-per-week'].hist(bins=10)
hist_plot.set_xlabel('hours-per-week')
hist_plot.set_ylabel('People')
# Out:
# Text(0, 0.5, 'People')

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows the working hours per week:
#                     - 0-30, 40-50,60-100 hours of working per week are below 5000 people
#                     - 50-60 are above 5000
#                     - 40-50 are exactly 25000

# %%
hist_plot=df['educational-num'].hist(bins=10)
hist_plot.set_xlabel('Education')
hist_plot.set_ylabel('People')
# Out:
# Text(0, 0.5, 'People')

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows the educational-num:
#                     - 8.4-11.8,13.1-14.2 are above 10000 people
#                     - rest all are below 2100

# %%
hist_plot=df['age'].hist(bins=10)
hist_plot.set_xlabel('age')
hist_plot.set_ylabel('People')
# Out:
# Text(0, 0.5, 'People')

# %% [markdown]
# <b>OBSERVATION</b> : This graph shows the age:
#                     - 25-45 are above 8000
#                     - rest all are below 7300

# %% [markdown]
# <h2>Bivariate Analysis</h2>

# %%
plt.figure(figsize=(25,7))
sns.pairplot(df)
plt.show()

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between all the numerical columns present in the dataset

# %%
sns.jointplot(x = 'hours-per-week' , y = 'educational-num' ,data = df,kind = 'scatter')
plt.show()

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between educational-num and hours-per-week in scattered plot

# %%
sns.jointplot(x = 'hours-per-week' , y = 'educational-num' ,data = df,kind = 'hex')
plt.show()

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between educational-num and hours-per-week in hexbin plot

# %%
sns.jointplot(x = 'age' , y = 'educational-num' ,data = df,kind = 'scatter')
plt.show()

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between educational-num and age

# %%
sns.jointplot(x = 'capital-gain' , y = 'capital-loss' ,data = df,kind = 'hex')
plt.show()

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation capital-gain and capital-loss in hexbin plot and showing that at 0 there is more concentration then rest

# %%
sns.boxplot(x='age',y='marital-status',data=df,hue='income')

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between marital-status and age in box plot  graph

# %%
sns.boxplot(x='hours-per-week',y='race',data=df,hue='gender')

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between hors-per-week and race in box plot  graph

# %%
sns.boxplot(x='educational-num',y='marital-status',data=df,hue='income')

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between marital-status and educational-num in box plot  graph

# %%
sns.boxplot(x='capital-gain',y='marital-status',data=df,hue='income')

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between marital-status and capital-gain in box plot  graph

# %%
sns.boxplot(x='capital-loss',y='marital-status',data=df,hue='income')

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between marital-status and capital-loss in box plot  graph

# %%
sns.barplot(x='gender',y='age',data=df,hue='income')

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between gender and age in bar plot  graph

# %%
sns.barplot(x='gender',y='hours-per-week',data=df,hue='income')

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between gender and hours-per-week in bar plot  graph

# %%
 sns.barplot(x='gender',y='educational-num',data=df,hue='income')

# %% [markdown]
# <b>OBSERVATION</b> : These graph shows the relation between gender and educational-num in bar plot  graph

# %% [markdown]
# <b>Conclusion</b>
# By analysis the dataset and it was consisting of many and manhy outlier that we remove and analysis the data..In this to identifiy the outlier box plot help the most to analysis data.Perfering boxplot was a good descion because there was any outlier and without boxplot it get difficult to plot but kde is get used to analysis proper distribution of numerical columns numerical column having very very low correlation so that it get diffcult to analysis and the variable columns get analysis with numerical columns and use income to differenitate them at end we preform normalization and convert the variable column in dummies

# %%
x = df['age'].value
data_scalling = preprocessing.MinMaxScaler()
new_df_scalling = data_scalling.fit_transform(df)
pd.DataFrame(new_df_scalling,columns=x)

x = df['educational-num'].value
data_scalling = preprocessing.MinMaxScaler()
new_df_scalling = data_scalling.fit_transform(df)
pd.DataFrame(new_df_scalling,columns=x)

x = df['hours-per-week'].value
data_scalling = preprocessing.MinMaxScaler()
new_df_scalling = data_scalling.fit_transform(df)
pd.DataFrame(new_df_scalling,columns=x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-158-7a0ff431a2d6> in <module>
# ----> 1 x = df['age'].value
#       2 data_scalling = preprocessing.MinMaxScaler()
#       3 new_df_scalling = data_scalling.fit_transform(df)
#       4 pd.DataFrame(new_df_scalling,columns=x)
#       5
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
